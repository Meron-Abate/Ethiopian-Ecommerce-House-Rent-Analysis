# %% [raw]
# #Importing libraries which used for making HTTP requests, adding delays, printing JSON data
# import requests
# import time
# import json

# %%
import requests  
import time      
import json 
# Configuration (API setup)

BASE_URL = "https://jiji.com.et/api_web/v1/listing"


PARAMS = {
    "filter_attr_179_property_type": "Condo",  
    "slug": "houses-apartments-for-rent",      
    "init_page": "true",                       
    "page": 1,                                 
    "webp": "true"                             
}

# HTTP headers to make our request look like a normal browser (to avoid being blocked)
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    ),
    "Accept": "application/json"
}


# Scraper Function

def scrape_listings(max_pages=3):
    
    all_listings = []
    current_page = 1

    while current_page <= max_pages:
        print(f"fetching page {current_page}")

        current_params = PARAMS.copy()
        current_params["page"] = current_page

        try:
            #send request
            response = requests.get(BASE_URL, params=current_params, headers=HEADERS, timeout=15)
            data = response.json()
            adverts_list = data["adverts_list"]

            if response.status_code == 200:
                data = response.json() # Converting API response from JSON to Python dictionary
                
                if data.get('status') == 'ok' and 'data' in data:
                    if 'adverts_list' in data and 'adverts' in data['adverts_list']:
                        listings = data['adverts_list']['adverts']
                    else:
                        listings = []

                    if listings: # Add this page's listings to the main list
                        all_listings.extend(listings)
                        print(f"added {len(listings)} listings from page {current_page}\n")
                        current_page += 1
                        time.sleep(2)
                    else:
                        print(f" No more listings found on page {current_page}.. Stoppin.\n")
                        break
                else:
                    print(" unexpected JSON structure.... stopping.")
                    print(json.dumps(data, indent=2, ensure_ascii=False))
                    break

            elif response.status_code == 404:
                print(f" Page {current_page} not found (404) Stopping\n")
                break
            else:
                print(f"Error fetching page {current_page} Status: {response.status_code}")
                print(response.text[:200])  # Show snippet for debugging
                break

        except requests.exceptions.Timeout:
            print(f" Request timed out for page {current_page}")
            break
        except requests.exceptions.ConnectionError:
            print(f" Connection error on page {current_page} Check your internet")
            break
        except requests.exceptions.RequestException as e:
            print(f" Unexpected error: {e}")
            break

    return all_listings


if __name__ == "__main__":
    print("Starting Jiji Condo Scraper...")
    scraped_condos = scrape_listings(max_pages=1)
    print(f"\nScraping complete! Total condos found: {len(scraped_condos)}")
    if scraped_condos:
        print("\n--- Sample of First 3 Listings ---")
        i = 1
        for listing in scraped_condos[:3]:
           print(f"\nListing {i}:")
           print(json.dumps(listing, indent=2, ensure_ascii=False))
           i += 1
           print("\n--- End of Sample ---")
        
        try:
            with open("jiji_condos.json", "w", encoding="utf-8") as file:
                json.dump(scraped_condos, file, indent=2, ensure_ascii=False)
            print("\nData successfully saved to jiji_condos.json")
        except Exception as e:
            print(f"Error saving data: {e}")
    else:
        print("No condos were scraped.")
# Out:
# Starting Jiji Condo Scraper...
# fetching page 1
#  unexpected JSON structure.... stopping.
# {
#   "adverts_list": {
#     "mode_default": "gallery",
#     "count": 247,
#     "adverts": [
#       {
#         "admin_info": {},
#         "as_top": false,
#         "attrs": [
#           {
#             "name": "Listing by",
#             "value": "Owner",
#             "unit": null
#           },
#           {
#             "name": "Property size",
#             "value": 76,
#             "unit": "sqm"
#           },
#           {
#             "name": "Furnishing",
#             "value": "Furnished",
#             "unit": null
#           },
#           {
#             "name": "Bedrooms",
#             "value": 2,
#             "unit": null,
#             "semantic_value": "2 bedrooms"
#           },
#           {
#             "name": "Bathrooms",
#             "value": 1,
#             "unit": null,
#             "semantic_value": "1 bathroom"
#           }
#         ],
# ...

# %%
import pandas as pd 
import requests
import json
import time


BASE_URL = "https://jiji.com.et/api_web/v1/listing"

PARAMS = {
    "filter_attr_179_property_type": "Condo", 
    "slug": "houses-apartments-for-rent", 
    "init_page": "true", #for prginstion
    "page": 1, # setting the first page
    "webp": "true" # images in a webp format
}

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept": "application/json"
}


#  function to normalize each listing 
def normalize_listing(item): #logic for transforming a single raw list dictionary (from the Jiji API) into a cleaner, flattened dictionary
    condo = {}
    condo["title"] = item.get("title")
    condo["url"] = "https://jiji.com.et" + item.get("url", "")
    condo["region"] = item.get("region")

    price_obj = item.get("price_obj", {}) # price obj is a nested dictionary 
    condo["price"] = price_obj.get("value")
    condo["price_display"] = price_obj.get("view")

    condo["bedrooms"] = None
    condo["bathrooms"] = None
    condo["furnishing"] = None
    condo["size_sqm"] = None

    for attr in item.get("attrs", []):
        if attr.get("name") == "Bedrooms": # go inside the attrs nested dictionary and get the name if the name is BEdrrom go and fetch the value and assign it to bedroom
            condo["bedrooms"] = attr.get("value")
        elif attr.get("name") == "Bathrooms":
            condo["bathrooms"] = attr.get("value")
        elif attr.get("name") == "Furnishing":
            condo["furnishing"] = attr.get("value")
        elif attr.get("name") == "Property size":
            condo["size_sqm"] = attr.get("value")

    condo["image_url"] = item.get("image_obj", {}).get("url")

    return condo

def scrape_listings(max_pages=3):
    
    all_listings = []
    current_page = 1

    while current_page <= max_pages:
        print(f"fetching page {current_page}")

        current_params = PARAMS.copy()
        current_params["page"] = current_page

        try:
            #send request
            response = requests.get(BASE_URL, params=current_params, headers=HEADERS, timeout=15)
            data = response.json()
            print(json.dumps(list(data.keys()), indent=2))
           

            if response.status_code == 200:
                
                if data.get('status') == 'ok' and 'adverts_list' in data:
                    listings = data['adverts_list'].get('adverts', [])
                else:
                     print("Unexpected JSON structure.... stopping.")
                     print(json.dumps(data, indent=2, ensure_ascii=False))
                     break
                    

                if listings: 
                     all_listings.extend(listings)
                     print(f"added {len(listings)} listings from page {current_page}\n")
                     current_page += 1
                     time.sleep(2)
                else:
                     print(f" No more listings found on page {current_page}.. Stoppin.\n")
                     break
                
            elif response.status_code == 404:
                print(f" Page {current_page} not found (404) Stopping\n")
                break
            else:
                print(f"Error fetching page {current_page} Status: {response.status_code}")
                print(response.text[:200])  
                break

        except requests.exceptions.Timeout:
            print(f" Request timed out for page {current_page}")
            break
        except requests.exceptions.ConnectionError:
            print(f" Connection error on page {current_page} Check your internet")
            break
        except requests.exceptions.RequestException as e:
            print(f" Unexpected error: {e}")
            break

    return all_listings

# --- Main execution ---
if __name__ == "__main__":
    print("Starting Jiji Condo Scraper...")
    scraped_condos = scrape_listings(max_pages=3)  

    print(f"\nScraping complete! Total condos found: {len(scraped_condos)}")

    if scraped_condos:
        # Normalize the listings
        normalized_listings = [] # empty list
        for item in scraped_condos: 
            normalized_item = normalize_listing(item)
            normalized_listings.append(normalized_item) 
        

        df_condos = pd.DataFrame(normalized_listings)

        print("\n--- Pandas DataFrame created ---")
       
        try: #saving JSOn
            with open("jiji_condos_normalized.json", "w", encoding="utf-8") as f:
                json.dump(normalized_listings, f, indent=2, ensure_ascii=False)
            print("\nNormalized data saved to jiji_condos_normalized.json")
        except Exception as e:
            print(f"Error saving normalized JSON: {e}")

       
        try: #saving as CSV
            df_condos.to_csv("jiji_condos_normalized.csv", index=False, encoding="utf-8")
            df_condos.dtypes
            
            print("\nNormalized data saved to jiji_condos_normalized.csv")
        except Exception as e:
            print(f"Error saving normalized CSV: {e}")

    else:
        print("No condos were scraped.")
# Out:
# Starting Jiji Condo Scraper...
# fetching page 1
# [
#   "adverts_list",
#   "companies_search",
#   "next_url",
#   "status",
#   "listing_id",
#   "extra_data",
#   "banners",
#   "banners_v2",
#   "sort_data",
#   "period",
#   "seo",
#   "seo_node_info",
#   "search_params",
#   "saved_search",
#   "search",
#   "adult_only",
#   "has_price_valuation",
#   "breadcrumbs",
#   "show_ads",
#   "search_categories",
#   "adsense_targeting"
# ]
# added 14 listings from page 1
#
# fetching page 2
# [
#   "adverts_list",
#   "companies_search",
#   "next_url",
#   "status",
#   "listing_id",
#   "extra_data"
# ]
# added 13 listings from page 2
#
# fetching page 3
# [
#   "adverts_list",
#   "companies_search",
#   "next_url",
#   "status",
#   "listing_id",
#   "extra_data"
# ]
# added 13 listings from page 3
#
#
# Scraping complete! Total condos found: 40
#
# --- Pandas DataFrame created ---
#
# Normalized data saved to jiji_condos_normalized.json
#
# ...

# %%
df_condos.describe()
# Out:
#               price   bedrooms  bathrooms    size_sqm
# count     40.000000  40.000000   40.00000   40.000000
# mean   19650.000000   2.250000    1.37500  103.000000
# std     5030.929975   0.669864    0.49029   98.921103
# min    13000.000000   1.000000    1.00000   54.000000
# 25%    16000.000000   2.000000    1.00000   76.000000
# 50%    19000.000000   2.000000    1.00000   86.000000
# 75%    21000.000000   3.000000    2.00000  105.000000
# max    35000.000000   3.000000    2.00000  703.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
try:
    df_condos = pd.read_csv("jiji_condos_normalized.csv")
    print("Data loaded successfully for visualization")
except FileNotFoundError:
    print("Error: 'jiji_condos_normalized.csv' not found.")
    exit()

# Set visual style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (15, 7)

plt.rcParams['font.size'] = 12

# Define bin width and create price bins in 5000 ETB intervals
bin_width = 5000
min_price = 0
max_price = df_condos['price'].max()
price_bins = np.arange(min_price, max_price + bin_width, bin_width)

# Create the histogram with KDE overlay
plt.figure(figsize=(15, 7))
sns.histplot(
    df_condos['price'],
    bins=price_bins,
    kde=True,
    alpha=0.6,
    line_kws={'linewidth': 2.5, 'color': 'red'}
)

# Plot titles and labels
plt.title('Distribution of Condo Prices (ETB) with 5,000 ETB Intervals')
plt.xlabel('Price (ETB)')
plt.ylabel('Number of Condos')

# Format x-axis
plt.xlim(0, 50000)
plt.xticks(np.arange(0, 50001, 5000))  # Show 0, 5000, 10000, ..., 50000
plt.ticklabel_format(style='plain', axis='x')  # Prevent scientific notation

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Data loaded successfully for visualization

# %%
df_condos.dtypes
# Out:
# title            object
# url              object
# region           object
# price             int64
# price_display    object
# bedrooms          int64
# bathrooms         int64
# furnishing       object
# size_sqm          int64
# image_url        object
# dtype: object

# %%
df_condos.groupby("bedrooms")["price"].mean()
# Out:
# bedrooms
# 1    17400.000000
# 2    18550.000000
# 3    21866.666667
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# --- Price Visualization ---

# 1. Histogram of Prices
plt.figure(figsize=(8, 5))
sns.histplot(df_condos["price"], bins=20, kde=True, color="skyblue")
plt.title("Distribution of Condo Prices")
plt.xlabel("Price (ETB)")
plt.ylabel("Number of Condos")
plt.tight_layout()
plt.show()

# 2. Boxplot of Prices (to detect outliers)
plt.figure(figsize=(6, 4))
sns.boxplot(y=df_condos["price"], color="lightgreen")
plt.title("Boxplot of Condo Prices")
plt.ylabel("Price (ETB)")
plt.tight_layout()
plt.show()

# %%
print("--- Overall Averages ---")
print(f"Average Condo Price: {df_analysis['price'].mean():,.2f} ETB")
print(f"Average Condo Size: {df_analysis['size_sqm'].mean():,.2f} sq.m")
print(f"Average Number of Bedrooms: {df_analysis['bedrooms'].mean():.2f}")
print(f"Average Number of Bathrooms: {df_analysis['bathrooms'].mean():.2f}")
print("\n")
# Out:
# --- Overall Averages ---
# Average Condo Price: 339,538.46 ETB
# Average Condo Size: 81.45 sq.m
# Average Number of Bedrooms: 2.12
# Average Number of Bathrooms: 1.28

# %%
print("--- Regional Price Extremes ---")
avg_price_by_region = df_analysis.groupby('region')['price'].mean().sort_values()

if not avg_price_by_region.empty:
    lowest_price_region = avg_price_by_region.index[0]
    lowest_price = avg_price_by_region.iloc[0]
    highest_price_region = avg_price_by_region.index[-1]
    highest_price = avg_price_by_region.iloc[-1]

    print(f"Region with Lowest Average Price: {lowest_price_region} ({lowest_price:,.2f} ETB)")
    print(f"Region with Highest Average Price: {highest_price_region} ({highest_price:,.2f} ETB)")
else:
    print("No regional price data available after cleaning.")
print("\n")
# Out:
# --- Regional Price Extremes ---
# Region with Lowest Average Price: Oromia Region, Oromia-Finfinne (17,000.00 ETB)
# Region with Highest Average Price: Addis Ababa, Yeka (366,100.00 ETB)

# %%
print("--- Average Price by Furnishing Status ---")
avg_price_by_furnishing = df_analysis.groupby('furnishing')['price'].mean().sort_values(ascending=False)

if not avg_price_by_furnishing.empty:
    print(avg_price_by_furnishing.apply(lambda x: f"{x:,.2f} ETB"))
else:
    print("No furnishing status data available after cleaning.")
print("\n")
# Out:
# --- Average Price by Furnishing Status ---
# furnishing
# Unfurnished       816,200.00 ETB
# Furnished         314,508.77 ETB
# Semi-Furnished     20,666.67 ETB
# Name: price, dtype: object

# %%
print("--- Most Common Bedroom Count & Its Average Price ---")
most_common_bedrooms = df_analysis['bedrooms'].mode()

if not most_common_bedrooms.empty:
    # If there's more than one mode (e.g., 2 and 3 bedrooms are equally common)
    for num_bedrooms in most_common_bedrooms:
        avg_price_for_mode = df_analysis[df_analysis['bedrooms'] == num_bedrooms]['price'].mean()
        print(f"Most common number of bedrooms: {num_bedrooms}")
        print(f"Average Price for {num_bedrooms}-bedroom condos: {avg_price_for_mode:,.2f} ETB")
else:
    print("No bedroom data available after cleaning.")
print("\n")
# Out:
# --- Most Common Bedroom Count & Its Average Price ---
# Most common number of bedrooms: 2
# Average Price for 2-bedroom condos: 408,029.41 ETB

# %%
import pandas as pd
import numpy as np

# --- 1. Load the DataFrame ---
try:
    df_condos = pd.read_csv("jiji_condos_normalized.csv")
    print("Data loaded successfully from 'jiji_condos_normalized.csv'.")
except FileNotFoundError:
    print("Error: 'jiji_condos_normalized.csv' not found. Please ensure it's in the correct directory.")
    


df_analysis = df_condos.copy()

# Convert relevant columns to numeric, coercing errors to NaN, then drop NaNs
df_analysis['price'] = pd.to_numeric(df_analysis['price'], errors='coerce')
df_analysis['bedrooms'] = pd.to_numeric(df_analysis['bedrooms'], errors='coerce')
df_analysis['bathrooms'] = pd.to_numeric(df_analysis['bathrooms'], errors='coerce')
df_analysis['size_sqm'] = pd.to_numeric(df_analysis['size_sqm'], errors='coerce')

# Drop rows where critical numerical columns are NaN after conversion
df_analysis.dropna(subset=['price', 'bedrooms', 'bathrooms', 'size_sqm'], inplace=True)

# Filter out non-positive values that don't make sense for condo features
df_analysis = df_analysis[df_analysis['price'] > 0]
df_analysis = df_analysis[df_analysis['bedrooms'] >= 0] # 0 bedrooms could be studios
df_analysis = df_analysis[df_analysis['bathrooms'] >= 0]
df_analysis = df_analysis[df_analysis['size_sqm'] > 0]

# Feature Engineering: Price per Square Meter (useful for value comparison)
# Ensure 'size_sqm' is not zero to avoid division by zero
df_analysis['price_per_sqm'] = df_analysis.apply(
    lambda row: row['price'] / row['size_sqm'] if row['size_sqm'] > 0 else np.nan, axis=1
)
# Drop rows where price_per_sqm might be NaN (e.g., if size_sqm was 0)
df_analysis.dropna(subset=['price_per_sqm'], inplace=True)


print(f"DataFrame 'df_analysis' prepared with {df_analysis.shape[0]} rows after cleaning.")

# --- 3. Filter for condos with price > 100,000 ETB ---
expensive_condos = df_analysis[df_analysis['price'] > 100000]

# --- 4. Print the URLs ---
print("\n--- URLs of Condos with Price > 100,000 ETB ---")
if not expensive_condos.empty:
    # Use .unique() to avoid printing the same URL multiple times if duplicates exist
    for url in expensive_condos['url'].unique():
        print(url)
else:
    print("No condos found with a price greater than 100,000 ETB after cleaning and filtering.")
# Out:
# Data loaded successfully from 'jiji_condos_normalized.csv'.
# DataFrame 'df_analysis' prepared with 65 rows after cleaning.
#
# --- URLs of Condos with Price > 100,000 ETB ---
# https://jiji.com.et/yeka/houses-apartments-for-rent/furnished-2bdrm-condo-in-ayaate-maberaate-xaayele-yamishathe-yeka-for-rent-w5DHEVFuaF2IpRQSAPYNBgfv.html?page=1&pos=6&cur_pos=6&ads_per_page=13&ads_count=242&lid=JVeS2FQxhd6wzA0t
# https://jiji.com.et/yeka/houses-apartments-for-rent/furnished-2bdrm-condo-in-yeka-for-rent-5XVGROae2UwdTV9RvuyJmSRw.html?page=1&pos=9&cur_pos=9&ads_per_page=13&ads_count=242&lid=JVeS2FQxhd6wzA0t
# https://jiji.com.et/yeka/houses-apartments-for-rent/1bdrm-condo-in-ayaate-maberaate-konedomeniyame-3nyaa-yeka-for-rent-wE3ZYdbRTbYZSb2DIYNrPNyl.html?page=2&pos=3&cur_pos=3&ads_per_page=13&ads_count=242&lid=0bsNs4oNA84X3LK1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker # Import ticker for formatting and locating
import os # For checking file existence

# --- 1. Load the DataFrame ---
try:
    df_condos = pd.read_csv("jiji_condos_normalized.csv")
    print("Data loaded successfully from 'jiji_condos_normalized.csv'.")
except FileNotFoundError:
    print("Error: 'jiji_condos_normalized.csv' not found. "
          "Creating a dummy DataFrame for demonstration purposes to allow execution.")
    # Create a dummy DataFrame for demonstration if file is not found
    dummy_data = {
        'title': ['Condo A', 'Condo B', 'Condo C', 'Condo D', 'Condo E', 'Condo F', 'Condo G', 'Condo H', 'Condo I', 'Condo J'],
        'price': [120000, 85000, 155000, 95000, 210000, 75000, 180000, 3500000, 4200000, 8000000],
        'bedrooms': [2, 1, 3, 2, 4, 1, 3, 5, 4, 6],
        'bathrooms': [2, 1, 3, 2, 4, 1, 3, 4, 3, 5],
        'size_sqm': [80, 50, 120, 70, 150, 45, 110, 250, 200, 300],
        'region': ['Bole', 'Megenagna', 'CMC', 'Bole', 'Megenagna', 'Bole', 'CMC', 'Sarbet', 'Bole', 'CMC'],
        'furnishing': ['Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Furnished', 'Unfurnished', 'Furnished'],
        'url': [f'http://jiji.com/{chr(97+i)}' for i in range(10)] # Generate dummy URLs
    }
    df_condos = pd.DataFrame(dummy_data)


# --- 2. Apply robust cleaning to create df_analysis ---
df_analysis = df_condos.copy()

# Convert relevant columns to numeric, coercing errors to NaN, then drop NaNs
df_analysis['price'] = pd.to_numeric(df_analysis['price'], errors='coerce')
df_analysis['bedrooms'] = pd.to_numeric(df_analysis['bedrooms'], errors='coerce')
df_analysis['bathrooms'] = pd.to_numeric(df_analysis['bathrooms'], errors='coerce')
df_analysis['size_sqm'] = pd.to_numeric(df_analysis['size_sqm'], errors='coerce')

# Drop rows where critical numerical columns are NaN after conversion
df_analysis.dropna(subset=['price', 'bedrooms', 'bathrooms', 'size_sqm'], inplace=True)

# Filter out non-positive values that don't make sense for condo features
df_analysis = df_analysis[df_analysis['price'] > 0]
df_analysis = df_analysis[df_analysis['bedrooms'] >= 0] # 0 bedrooms could be studios
df_analysis = df_analysis[df_analysis['bathrooms'] >= 0]
df_analysis = df_analysis[df_analysis['size_sqm'] > 0]

# Feature Engineering: Price per Square Meter
df_analysis['price_per_sqm'] = df_analysis.apply(
    lambda row: row['price'] / row['size_sqm'] if row['size_sqm'] > 0 else np.nan, axis=1
)
df_analysis.dropna(subset=['price_per_sqm'], inplace=True)

# Ensure 'bedrooms' is treated as an integer category for grouping/plotting
df_analysis['bedrooms'] = df_analysis['bedrooms'].astype(int)

print(f"DataFrame 'df_analysis' prepared with {df_analysis.shape[0]} rows before filtering for price <= 100,000.")


# --- NEW STEP: Filter out data where price is greater than 100,000 ---
initial_rows = df_analysis.shape[0]
df_analysis_filtered = df_analysis[df_analysis['price'] <= 100000].copy() # .copy() to avoid SettingWithCopyWarning
filtered_rows = df_analysis_filtered.shape[0]

print(f"Data filtered: {initial_rows - filtered_rows} rows removed (price > 100,000 ETB).")
print(f"DataFrame 'df_analysis_filtered' now has {filtered_rows} rows.")

# --- Analysis: Average Price by Number of Bedrooms on FILTERED data ---

# Calculate the average price for each number of bedrooms using the FILTERED DataFrame
# Filter out extremely high bedroom counts for cleaner visualization (e.g., >6 bedrooms)
average_price_by_bedrooms = df_analysis_filtered[df_analysis_filtered['bedrooms'] <= 6].groupby('bedrooms')['price'].mean().reset_index()

# Sort by bedrooms for consistent plotting order
average_price_by_bedrooms = average_price_by_bedrooms.sort_values(by='bedrooms')


# --- Visualization: Bar Chart of Average Price vs. Bedrooms on FILTERED data ---
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

if average_price_by_bedrooms.empty:
    print("\nNo relevant data to plot for average price by bedrooms after filtering for prices <= 100,000 ETB.")
else:
    plt.figure(figsize=(10, 6))

    # Create the bar plot
    sns.barplot(x='bedrooms', y='price', data=average_price_by_bedrooms, palette='viridis')

    plt.title('Average Condo Price by Number of Bedrooms (Price <= 100,000 ETB)')
    plt.xlabel('Number of Bedrooms')
    plt.ylabel('Average Price (ETB)')

    # Apply formatting for the y-axis (price)
    ax = plt.gca() # Get the current axes

    # --- APPLYING COMMA FORMAT TO Y-AXIS (PRICE) ---
    formatter = mticker.FuncFormatter(lambda x, p: f'{int(x):,}')
    ax.yaxis.set_major_formatter(formatter)

    # Optional: Set y-axis limits to start from 0 for clarity
    ax.set_ylim(bottom=0)

    # Adjust y-axis tick interval if needed for the new, smaller range
    # Since max is 100,000, 5,000 or 10,000 might be appropriate
    ax.yaxis.set_major_locator(mticker.MultipleLocator(10000)) # Example: ticks every 10,000 ETB

    plt.tight_layout() # Adjust layout to prevent labels from overlapping
    plt.show()
# Out:
# Data loaded successfully from 'jiji_condos_normalized.csv'.
# DataFrame 'df_analysis' prepared with 65 rows before filtering for price <= 100,000.
# Data filtered: 4 rows removed (price > 100,000 ETB).
# DataFrame 'df_analysis_filtered' now has 61 rows.
# C:\Users\HP\AppData\Local\Temp\ipykernel_15280\187705969.py:88: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='bedrooms', y='price', data=average_price_by_bedrooms, palette='viridis')

# %%
import pandas as pd
import numpy as np
import os

# --- 1. Load the DataFrame ---
try:
    df_condos = pd.read_csv("jiji_condos_normalized.csv")
    print("Data loaded successfully from 'jiji_condos_normalized.csv'.")
except FileNotFoundError:
    print("Error: 'jiji_condos_normalized.csv' not found. "
          "Creating a dummy DataFrame for demonstration purposes to allow execution.")
    # Create a dummy DataFrame for demonstration if file is not found
    dummy_data = {
        'title': ['Condo A', 'Condo B', 'Condo C', 'Condo D', 'Condo E', 'Condo F', 'Condo G', 'Condo H', 'Condo I', 'Condo J', 'Condo K', 'Condo L', 'Condo M', 'Condo N', 'Condo O', 'Condo P', 'Condo Q', 'Condo R', 'Condo S', 'Condo T'],
        'price': [120000, 85000, 155000, 95000, 210000, 75000, 180000, 3500000, 4200000, 8000000, 90000, 110000, 130000, 600000, 75000, 98000, 5000000, 60000, 70000, 82000],
        'bedrooms': [2, 1, 3, 2, 4, 1, 3, 5, 4, 6, 1, 2, 2, 3, 1, 1, 5, 2, 1, 2],
        'bathrooms': [2, 1, 3, 2, 4, 1, 3, 4, 3, 5, 1, 2, 2, 3, 1, 1, 4, 1, 1, 2],
        'size_sqm': [80, 50, 120, 70, 150, 45, 110, 250, 200, 300, 40, 60, 85, 150, 38, 50, 220, 55, 48, 65],
        'region': ['Bole', 'Megenagna', 'CMC', 'Bole', 'Megenagna', 'Bole', 'CMC', 'Sarbet', 'Bole', 'CMC', 'Lideta', 'Sarbet', 'Bole', 'Megenagna', 'Lideta', 'Bole', 'CMC', 'Lideta', 'Bole', 'CMC'],
        'furnishing': ['Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished'],
        'url': [f'http://jiji.com/{chr(97+i)}' for i in range(20)]
    }
    df_condos = pd.DataFrame(dummy_data)


# --- 2. Apply robust cleaning to create df_analysis ---
df_analysis = df_condos.copy()

# Convert relevant columns to numeric, coercing errors to NaN, then drop NaNs
df_analysis['price'] = pd.to_numeric(df_analysis['price'], errors='coerce')
df_analysis['bedrooms'] = pd.to_numeric(df_analysis['bedrooms'], errors='coerce')
df_analysis['bathrooms'] = pd.to_numeric(df_analysis['bathrooms'], errors='coerce')
df_analysis['size_sqm'] = pd.to_numeric(df_analysis['size_sqm'], errors='coerce')

# Drop rows where critical numerical columns are NaN after conversion
df_analysis.dropna(subset=['price', 'bedrooms', 'bathrooms', 'size_sqm'], inplace=True)

# Filter out non-positive values that don't make sense for condo features
df_analysis = df_analysis[df_analysis['price'] > 0]
df_analysis = df_analysis[df_analysis['bedrooms'] >= 0] # 0 bedrooms could be studios
df_analysis = df_analysis[df_analysis['bathrooms'] >= 0]
df_analysis = df_analysis[df_analysis['size_sqm'] > 0]

# Feature Engineering: Price per Square Meter
df_analysis['price_per_sqm'] = df_analysis.apply(
    lambda row: row['price'] / row['size_sqm'] if row['size_sqm'] > 0 else np.nan, axis=1
)
df_analysis.dropna(subset=['price_per_sqm'], inplace=True)

# Ensure 'bedrooms' is treated as an integer category
df_analysis['bedrooms'] = df_analysis['bedrooms'].astype(int)

print(f"DataFrame 'df_analysis' initially has {df_analysis.shape[0]} rows after general cleaning.")


# --- Filter out data where price is greater than 100,000 ---
initial_rows = df_analysis.shape[0]
df_analysis_filtered = df_analysis[df_analysis['price'] <= 100000].copy()
filtered_rows = df_analysis_filtered.shape[0]
removed_rows = initial_rows - filtered_rows

print(f"Data filtered: {removed_rows} rows removed (price > 100,000 ETB).")
print(f"DataFrame 'df_analysis_filtered' now has {filtered_rows} rows.")


# --- NEW STEP: Sort the filtered DataFrame by 'bedrooms' ---
df_analysis_sorted = df_analysis_filtered.sort_values(by='bedrooms').copy()

# --- Display Price and Bedrooms for the SORTED & FILTERED DataFrame ---

# Set display options to ensure all rows are shown (use cautiously for very large DataFrames)
pd.set_option('display.max_rows', None) # Set to None to display all rows
pd.set_option('display.max_columns', None) # Not strictly needed for 2 columns, but good practice

print("\n--- Filtered Condos (Price <= 100,000 ETB), Sorted by Bedrooms ---")

# Create a temporary formatted price column for display
df_analysis_sorted['price_formatted'] = df_analysis_sorted['price'].apply(lambda x: f'{int(x):,}')

# Print the selected columns from the SORTED and FILTERED DataFrame
print(df_analysis_sorted[['bedrooms', 'price_formatted']]) # Display bedrooms first as per request

# Reset display options to default after printing (optional)
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# Data loaded successfully from 'jiji_condos_normalized.csv'.
# DataFrame 'df_analysis' initially has 65 rows after general cleaning.
# Data filtered: 4 rows removed (price > 100,000 ETB).
# DataFrame 'df_analysis_filtered' now has 61 rows.
#
# --- Filtered Condos (Price <= 100,000 ETB), Sorted by Bedrooms ---
#     bedrooms price_formatted
# 1          1          23,000
# 7          1          27,000
# 18         1          19,000
# 21         1          16,000
# 29         1          19,000
# 31         1          12,000
# 26         1          20,000
# 35         1          18,000
# 55         1          20,000
# 46         1          12,000
# 41         1          23,000
# 25         2          18,000
# 13         2          26,000
# 11         2          18,000
# 12         2          12,000
# 2          2          15,000
# 27         2          14,000
# 34         2          16,000
# 24         2          16,000
# 19         2          14,000
# 58         2          13,000
# ...

# %%
import pandas as pd
import numpy as np
import os

# --- The Average Price Calculation Function ---
def calculate_average_price_by_bedrooms(df):
    """
    Calculates the average price for each number of bedrooms in a DataFrame.

    Args:
        df (pd.DataFrame): The input DataFrame containing 'bedrooms' and 'price' columns.
                          It's assumed this DataFrame is already cleaned and filtered
                          according to your requirements (e.g., price <= 100,000 ETB).

    Returns:
        pd.DataFrame: A DataFrame with 'bedrooms' and 'average_price_etb' columns,
                      sorted by bedrooms, or None if input df is empty or has no relevant data.
    """
    if df.empty:
        print("Input DataFrame is empty. Cannot calculate averages.")
        return None

    # Filter out extremely high bedroom counts that might be outliers or sparse data
    # (e.g., >6 bedrooms might not have enough samples in common condo datasets)
    relevant_bedrooms_df = df[df['bedrooms'] >= 0].copy() # Ensure non-negative bedrooms
    relevant_bedrooms_df = relevant_bedrooms_df[relevant_bedrooms_df['bedrooms'] <= 6].copy()

    if relevant_bedrooms_df.empty:
        print("No relevant bedroom data (0-6 bedrooms) found in the DataFrame to calculate averages.")
        return None

    average_prices = relevant_bedrooms_df.groupby('bedrooms')['price'].mean().reset_index()
    average_prices = average_prices.sort_values(by='bedrooms')

    # Format the average price for display
    average_prices['average_price_etb'] = average_prices['price'].apply(lambda x: f'{x:,.2f}')

    return average_prices[['bedrooms', 'average_price_etb']]


# --- Example Usage: Full context to run the function ---

# --- Load the DataFrame ---
try:
    df_condos = pd.read_csv("jiji_condos_normalized.csv")
    print("Data loaded successfully from 'jiji_condos_normalized.csv'.")
except FileNotFoundError:
    print("Error: 'jiji_condos_normalized.csv' not found. "
          "Creating a dummy DataFrame for demonstration purposes to allow execution.")
    dummy_data = {
        'title': ['Condo A', 'Condo B', 'Condo C', 'Condo D', 'Condo E', 'Condo F', 'Condo G', 'Condo H', 'Condo I', 'Condo J', 'Condo K', 'Condo L', 'Condo M', 'Condo N', 'Condo O', 'Condo P', 'Condo Q', 'Condo R', 'Condo S', 'Condo T'],
        'price': [120000, 85000, 155000, 95000, 210000, 75000, 180000, 3500000, 4200000, 8000000, 90000, 110000, 130000, 600000, 75000, 98000, 5000000, 60000, 70000, 82000],
        'bedrooms': [2, 1, 3, 2, 4, 1, 3, 5, 4, 6, 1, 2, 2, 3, 1, 1, 5, 2, 1, 2],
        'bathrooms': [2, 1, 3, 2, 4, 1, 3, 4, 1, 5, 1, 2, 2, 3, 1, 1, 4, 1, 1, 2],
        'size_sqm': [80, 50, 120, 70, 150, 45, 110, 250, 200, 300, 40, 60, 85, 150, 38, 50, 220, 55, 48, 65],
        'region': ['Bole', 'Megenagna', 'CMC', 'Bole', 'Megenagna', 'Bole', 'CMC', 'Sarbet', 'Bole', 'CMC', 'Lideta', 'Sarbet', 'Bole', 'Megenagna', 'Lideta', 'Bole', 'CMC', 'Lideta', 'Bole', 'CMC'],
        'furnishing': ['Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished', 'Furnished', 'Furnished', 'Unfurnished', 'Furnished', 'Unfurnished'],
        'url': [f'http://jiji.com/{chr(97+i)}' for i in range(20)]
    }
    df_condos = pd.DataFrame(dummy_data)


# --- Apply robust cleaning to create df_analysis ---
df_analysis = df_condos.copy()
df_analysis['price'] = pd.to_numeric(df_analysis['price'], errors='coerce')
df_analysis['bedrooms'] = pd.to_numeric(df_analysis['bedrooms'], errors='coerce')
df_analysis['bathrooms'] = pd.to_numeric(df_analysis['bathrooms'], errors='coerce')
df_analysis['size_sqm'] = pd.to_numeric(df_analysis['size_sqm'], errors='coerce')
df_analysis.dropna(subset=['price', 'bedrooms', 'bathrooms', 'size_sqm'], inplace=True)
df_analysis = df_analysis[df_analysis['price'] > 0]
df_analysis = df_analysis[df_analysis['bedrooms'] >= 0]
df_analysis = df_analysis[df_analysis['bathrooms'] >= 0]
df_analysis = df_analysis[df_analysis['size_sqm'] > 0]
df_analysis['price_per_sqm'] = df_analysis.apply(
    lambda row: row['price'] / row['size_sqm'] if row['size_sqm'] > 0 else np.nan, axis=1
)
df_analysis.dropna(subset=['price_per_sqm'], inplace=True)
df_analysis['bedrooms'] = df_analysis['bedrooms'].astype(int)


# --- Filter data for price <= 100,000 (as per your previous request) ---
df_analysis_filtered = df_analysis[df_analysis['price'] <= 100000].copy()

# --- Call the function and print the result ---
print("\n--- Using the 'calculate_average_price_by_bedrooms' function ---")
average_prices_result = calculate_average_price_by_bedrooms(df_analysis_filtered)

if average_prices_result is not None:
    print(average_prices_result)
    print("\nNote: Prices are in ETB.")
else:
    print("Could not calculate averages. Please check the data.")
# Out:
# Data loaded successfully from 'jiji_condos_normalized.csv'.
#
# --- Using the 'calculate_average_price_by_bedrooms' function ---
#    bedrooms average_price_etb
# 0         1         19,000.00
# 1         2         17,906.25
# 2         3         22,466.67
# 3         4         17,000.00
#
# Note: Prices are in ETB.
